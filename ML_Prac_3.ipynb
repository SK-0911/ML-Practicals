# %% [markdown]
# <a href="https://colab.research.google.com/github/SK-0911/ML-Practicals/blob/main/ML_Prac_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame(data={"Temperature": [1,np.nan,3,2,3],
                  "Humidity": [1,np.nan,3,np.nan,5]})
df
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 1          NaN       NaN
# 2          3.0       3.0
# 3          2.0       NaN
# 4          3.0       5.0

# %%
df.isnull()
# Out:
#    Temperature  Humidity
# 0        False     False
# 1         True      True
# 2        False     False
# 3        False      True
# 4        False     False

# %%
df.isnull().sum()
# Out:
# Temperature    1
# Humidity       2
# dtype: int64

# %%
missing_values = ["N/a", "na", np.nan]

# %%
df1 = pd.read_csv("test_data_cleaning.csv", na_values=missing_values)
df1
# Out:
#          id keyword location  \
# 0         0     NaN      NaN
# 1         2     NaN      NaN
# 2         3     NaN      NaN
# 3         9     NaN      NaN
# 4        11     NaN      NaN
# ...     ...     ...      ...
# 3258  10861     NaN      NaN
# 3259  10865     NaN      NaN
# 3260  10868     NaN      NaN
# 3261  10874     NaN      NaN
# 3262  10875     NaN      NaN
#
#                                                    text
# 0                    Just happened a terrible car crash
# 1     Heard about  # earthquake is different cities,...
# 2     there is a forest fire at spot pond, geese are...
# 3        Apocalypse lighting .   # Spokane  # wildfires
# 4         Typhoon Soudelor kills 28 in China and Taiwan
# ...                                                 ...
# 3258  EARTHQUAKE SAFETY LOS ANGELES  SAFETY FASTENER...
# 3259  Storm in RI worse than last hurricane .  My ci...
# 3260                  Green Line derailment in Chicago
# ...

# %%
df1.isnull().sum()
# Out:
# id             0
# keyword       26
# location    1105
# text           0
# dtype: int64

# %%
df1.isnull().any()
# Out:
# id          False
# keyword      True
# location     True
# text        False
# dtype: bool

# %%
df
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 1          NaN       NaN
# 2          3.0       3.0
# 3          2.0       NaN
# 4          3.0       5.0

# %%
sns.heatmap(df, yticklabels=False, annot=True)

# %%
df
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 1          NaN       NaN
# 2          3.0       3.0
# 3          2.0       NaN
# 4          3.0       5.0

# %%
df.dropna()
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 2          3.0       3.0
# 4          3.0       5.0

# %%
df.fillna(0)
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 1          0.0       0.0
# 2          3.0       3.0
# 3          2.0       0.0
# 4          3.0       5.0

# %%
df.fillna(method='ffill') #Forward Fill(Fills the data of previous row)
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 1          1.0       1.0
# 2          3.0       3.0
# 3          2.0       3.0
# 4          3.0       5.0

# %%
df.fillna(method='bfill') #Backward Fill(Fills the data of next row)
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 1          3.0       3.0
# 2          3.0       3.0
# 3          2.0       5.0
# 4          3.0       5.0

# %%
df.interpolate()  #Interpolate takes the avg value of next and previous row and fill it with that avg
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 1          2.0       2.0
# 2          3.0       3.0
# 3          2.0       4.0
# 4          3.0       5.0

# %%
df.fillna({'Temperature': 43})
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 1         43.0       NaN
# 2          3.0       3.0
# 3          2.0       NaN
# 4          3.0       5.0

# %%
df.fillna({'Humidity': 4})
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 1          NaN       4.0
# 2          3.0       3.0
# 3          2.0       4.0
# 4          3.0       5.0

# %%
df.sort_values(by=['Temperature'])  #Sort values by Temperature
# Out:
#    Temperature  Humidity
# 0          1.0       1.0
# 3          2.0       NaN
# 2          3.0       3.0
# 4          3.0       5.0
# 1          NaN       NaN

# %%
gb = df.groupby(['Humidity'])   #Group by Humidity
gb.first()
# Out:
#           Temperature
# Humidity
# 1.0               1.0
# 3.0               3.0
# 5.0               3.0
